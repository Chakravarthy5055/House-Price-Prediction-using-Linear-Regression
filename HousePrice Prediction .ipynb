# %% [markdown]
# ## importing libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## importing data

# %%
tb=pd.read_csv('chennai.csv')
tb.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
tb.shape
# Out:
# (7109, 22)

# %% [markdown]
# ## Analyzing data

# %%
tb.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# ...

# %%
tb.describe(include='all')
# Out:
#         PRT_ID      AREA     INT_SQFT   DATE_SALE  DIST_MAINROAD    N_BEDROOM  \
# count     7109      7109  7109.000000        7109    7109.000000  7108.000000
# unique    7109        17          NaN        2798            NaN          NaN
# top     P03210  Chrompet          NaN  06-10-2009            NaN          NaN
# freq         1      1681          NaN          12            NaN          NaN
# mean       NaN       NaN  1382.073006         NaN      99.603179     1.637029
# std        NaN       NaN   457.410902         NaN      57.403110     0.802902
# min        NaN       NaN   500.000000         NaN       0.000000     1.000000
# 25%        NaN       NaN   993.000000         NaN      50.000000     1.000000
# 50%        NaN       NaN  1373.000000         NaN      99.000000     1.000000
# 75%        NaN       NaN  1744.000000         NaN     148.000000     2.000000
# max        NaN       NaN  2500.000000         NaN     200.000000     4.000000
#
# ...

# %%
tb.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
tb.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DATE_SALE         object
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# DATE_BUILD        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# REG_FEE            int64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
temp = pd.DataFrame(index=tb.columns)
temp['data_types']=tb.dtypes
temp['null_count'] = tb.isnull().sum()
temp['unique_count'] = tb.nunique()
temp
# Out:
#               data_types  null_count  unique_count
# PRT_ID            object           0          7109
# AREA              object           0            17
# INT_SQFT           int64           0          1699
# DATE_SALE         object           0          2798
# DIST_MAINROAD      int64           0           201
# N_BEDROOM        float64           1             4
# N_BATHROOM       float64           5             2
# N_ROOM             int64           0             5
# SALE_COND         object           0             9
# PARK_FACIL        object           0             3
# DATE_BUILD        object           0          5808
# BUILDTYPE         object           0             5
# UTILITY_AVAIL     object           0             5
# STREET            object           0             5
# MZZONE            object           0             6
# QS_ROOMS         float64           0            31
# QS_BATHROOM      float64           0            31
# ...

# %%
tb['SALES_PRICE'].plot.hist(bins=50)
plt.xlabel('Sales',fontsize=12)
# Out:
# Text(0.5, 0, 'Sales')

# %%
(tb['SALES_PRICE'].loc[tb['SALES_PRICE']<18000000]).plot.hist(bins=50)
plt.xlabel('Sales',fontsize=12)
# Out:
# Text(0.5, 0, 'Sales')

# %%
tb['INT_SQFT'].plot.hist(bins = 50)
plt.xlabel('Area in sq feet', fontsize=12)
# Out:
# Text(0.5, 0, 'Area in sq feet')

# %%
tb['N_BEDROOM'].value_counts()
# Out:
# 1.0    3795
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64

# %%
tb['N_BEDROOM'].value_counts()/len(tb)*100
# Out:
# 1.0    53.383036
# 2.0    33.084822
# 3.0     9.945140
# 4.0     3.572936
# Name: N_BEDROOM, dtype: float64

# %%
len(tb)
# Out:
# 7109

# %%
tb['N_ROOM'].value_counts()
# Out:
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64

# %%
tb['N_BATHROOM'].value_counts()
# Out:
# 1.0    5589
# 2.0    1515
# Name: N_BATHROOM, dtype: int64

# %%
tb['N_BATHROOM'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
tb['AREA'].value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64

# %%
tb['AREA'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
tb['PARK_FACIL'].value_counts()
# Out:
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64

# %%
tb['PARK_FACIL'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
tb.shape
# Out:
# (7109, 22)

# %% [markdown]
# ## dropping duplicate values

# %%
tb.drop_duplicates(inplace=True)

# %%
tb.head(2)
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# 0      4.0         3.9         4.9       4.330   380000  144400      7600000
# 1      4.9         4.2         2.5       3.765   760122  304049     21717770
#
# [2 rows x 22 columns]

# %%
tb.shape
# Out:
# (7109, 22)

# %% [markdown]
# ## finding and filling null values

# %%
tb.dropna(axis=0, how='any')
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# ...

# %%
tb.dropna(axis=1, how='any')
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_ROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131       3
# 1     P09411  Anna Nagar      1986  19-12-2006             26       5
# 2     P01812       Adyar       909  04-02-2012             70       3
# 3     P05346   Velachery      1855  13-03-2010             14       5
# 4     P06210  Karapakkam      1226  05-10-2009             84       3
# ...      ...         ...       ...         ...            ...     ...
# 7104  P03834  Karapakkam       598  03-01-2011             51       2
# 7105  P10000   Velachery      1897  08-04-2004             52       5
# 7106  P09594   Velachery      1614  25-08-2006            152       4
# 7107  P06508  Karapakkam       787  03-08-2009             40       2
# 7108  P09794   Velachery      1896  13-07-2005            156       5
#
#         SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE UTILITY_AVAIL     STREET  \
# ...

# %%
tb['N_BEDROOM'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
tb['N_BEDROOM'].mode()[0]
# Out:
# 1.0

# %%
tb['N_BEDROOM'].fillna(value = (tb['N_BEDROOM'].mode()[0]), inplace=True)

# %%
tb.loc[tb['N_BATHROOM'].isnull()==True]
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 70    P05304  Anna Nagar      1589  22-03-2010             39        1.0
# 5087  P01333    Chrompet      1016  02-08-2012            105        1.0
# 6134  P01332    Chormpet       916  02-08-2012            173        1.0
# 6371  P01189    Chrompet      1035  06-11-2012             90        1.0
# 6535  P09189  Anna Nagar      1864  05-03-2007            184        2.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# 70           NaN       4      Partial         No  ...        AllPub
# 5087         NaN       3     AbNormal        Yes  ...       NoSewr
# 6134         NaN       3  Normal Sale        Yes  ...           ELO
# 6371         NaN       3      Partial         No  ...        NoSeWa
# 6535         NaN       5       Family        Yes  ...       NoSewr
#
#          STREET MZZONE QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  \
# ...

# %%
tb['N_BATHROOM'].fillna(value =2.0, inplace=True)

# %%
tb.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         0
# N_BATHROOM        0
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
def fill_na(x):
    return ((x['QS_ROOMS'] + x['QS_BATHROOM'] + x['QS_BEDROOM'])/3)
tb['QS_OVERALL']=tb.apply(lambda x:fill_na(x) if pd.isnull(x['QS_OVERALL']) else x['QS_OVERALL'],axis=1)
tb.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
tb.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DATE_SALE         object
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# DATE_BUILD        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# REG_FEE            int64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
tb = tb.astype({'N_BEDROOM': 'object', 'N_ROOM': 'object', 'N_BATHROOM': 'object'})

# %%
tb.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DATE_SALE         object
# DIST_MAINROAD      int64
# N_BEDROOM         object
# N_BATHROOM        object
# N_ROOM            object
# SALE_COND         object
# PARK_FACIL        object
# DATE_BUILD        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# REG_FEE            int64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
tb['PARK_FACIL'].replace({'Noo':'No'},inplace = True)
tb['PARK_FACIL'].value_counts()
# Out:
# Yes    3587
# No     3522
# Name: PARK_FACIL, dtype: int64

# %%
temp = ['AREA','N_BEDROOM','N_BATHROOM','N_ROOM','SALE_COND','PARK_FACIL','BUILDTYPE','UTILITY_AVAIL','STREET','MZZONE']
for i in temp:
    print('************Value count in',i,'********')
    print(tb[i].value_counts())
# Out:
# ************Value count in AREA ********
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64
# ************Value count in N_BEDROOM ********
# 1.0    3796
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64
# ************Value count in N_BATHROOM ********
# 1.0    5589
# 2.0    1520
# Name: N_BATHROOM, dtype: int64
# ************Value count in N_ROOM ********
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64
# ************Value count in SALE_COND ********
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# Family         1403
# Adj Land          6
# ...

# %%
tb['AREA'].replace({'TNagar':'T Nagar', 'Adyr': 'Adyar', 'KKNagar': 'KK Nagar',  
                    'Chrompt': 'Chrompet', 'Chormpet': 'Chrompet','Chrmpet': 'Chrompet',
                    'Ana Nagar': 'Anna Nagar', 'Ann Nagar': 'Anna Nagar',
                     'Karapakam': 'Karapakkam' , 'Velchery': 'Velachery'}, inplace = True)
tb['AREA'].value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
tb['SALE_COND'].replace({'PartiaLl':'Partial', 'Partiall': 'Partial', 
                         'Adj Land': 'AdjLand',  
                         'Ab Normal': 'AbNormal'}, inplace = True)
tb['SALE_COND'].value_counts()
# Out:
# AdjLand        1439
# Partial        1433
# Normal Sale    1423
# AbNormal       1411
# Family         1403
# Name: SALE_COND, dtype: int64

# %%
tb['BUILDTYPE'].replace({'Comercial':'Commercial', 'Other': 'Others'},inplace = True)
tb['UTILITY_AVAIL'].replace({'All Pub':'AllPub'},inplace = True)
tb['STREET'].replace({'NoAccess':'No Access', 'Pavd':'Paved'},inplace = True)

# %%
tb.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
tb.plot.scatter('INT_SQFT','SALES_PRICE')
# Out:
# <AxesSubplot:xlabel='INT_SQFT', ylabel='SALES_PRICE'>

# %%
tb['BUILDTYPE'].head()
# Out:
# 0    Commercial
# 1    Commercial
# 2    Commercial
# 3        Others
# 4        Others
# Name: BUILDTYPE, dtype: object

# %%
fig,ax=plt.subplots()
colors={'Commercial':'red','Others':'green','House':'blue'}
ax.scatter(tb['INT_SQFT'], tb['SALES_PRICE'],c=tb['BUILDTYPE'].apply(lambda x:colors[x]))
plt.show()

# %%
tb.plot.scatter('QS_OVERALL', 'SALES_PRICE')
# Out:
# <AxesSubplot:xlabel='QS_OVERALL', ylabel='SALES_PRICE'>

# %%
fig, axs = plt.subplots(2, 2)

fig.set_figheight(10)
fig.set_figwidth(10)

axs[0, 0].scatter(tb['QS_BEDROOM'], tb['SALES_PRICE'])    # QS_BEDROOM and sale price
axs[0, 0].set_title('QS_BEDROOM')

axs[0, 1].scatter(tb['QS_BATHROOM'], tb['SALES_PRICE'])   # QS_BATHROOM and price
axs[0, 1].set_title('QS_BATHROOM')

axs[1, 0].scatter(tb['QS_ROOMS'], tb['SALES_PRICE'])    # QS_ROOMS and sale price
axs[1, 0].set_title('QS_ROOMS')

axs[1, 1].scatter(tb['QS_OVERALL'], tb['SALES_PRICE'])    # QS_OVERALL and sale price
axs[1, 1].set_title('QS_OVERALL')
# Out:
# Text(0.5, 1.0, 'QS_OVERALL')

# %%
ax = plt.figure().add_subplot(111)
bp = ax.boxplot([tb['QS_BEDROOM'], tb['QS_ROOMS'], tb['QS_BATHROOM'], tb['QS_OVERALL']])

# %%
tb.head(2)
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131       1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26       2.0
#
#   N_BATHROOM N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0        1.0      3  AbNormal        Yes  ...        AllPub   Paved      A
# 1        1.0      5  AbNormal         No  ...        AllPub  Gravel     RH
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# 0      4.0         3.9         4.9       4.330   380000  144400      7600000
# 1      4.9         4.2         2.5       3.765   760122  304049     21717770
#
# [2 rows x 22 columns]

# %%
tb.drop(['PRT_ID'],axis=1,inplace=True)

# %%
tb=pd.get_dummies(tb)

# %%
x = tb.drop('SALES_PRICE', axis=1)
y= tb['SALES_PRICE']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.3)

train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((4976, 8655), (2133, 8655), (4976,), (2133,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
lreg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
lreg.predict(test_x)
# Out:
# array([18988794.45383269,  8825215.99801371,  9551771.71652664, ...,
#         9219259.25247909,  6479398.9602705 , 16014190.13549403])

# %%
test_y
# Out:
# 478     19609810
# 5840     9524080
# 626      9963440
# 5456    11938300
# 2330    12192300
#           ...
# 4760    14554600
# 1931    16616430
# 5633     8967625
# 1589     6486150
# 632     17733960
# Name: SALES_PRICE, Length: 2133, dtype: int64

# %%
lreg.score(test_x,test_y)
# Out:
# 0.9296092699195576

# %%
tb
# Out:
#       INT_SQFT  DIST_MAINROAD  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# 0         1004            131       4.0          3.9         4.9       4.330
# 1         1986             26       4.9          4.2         2.5       3.765
# 2          909             70       4.1          3.8         2.2       3.090
# 3         1855             14       4.7          3.9         3.6       4.010
# 4         1226             84       3.0          2.5         4.1       3.290
# ...        ...            ...       ...          ...         ...         ...
# 7104       598             51       3.0          2.2         2.4       2.520
# 7105      1897             52       3.6          4.5         3.3       3.920
# 7106      1614            152       4.3          4.2         2.9       3.840
# 7107       787             40       4.6          3.8         4.1       4.160
# 7108      1896            156       3.1          3.5         4.3       3.640
#
# ...
